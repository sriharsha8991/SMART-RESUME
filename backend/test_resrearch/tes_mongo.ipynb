# %%
user@example.com
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # user@example.com
# ----> 2 from ..profile.mongo import student_collection
#       3 await student_collection.find_one({"email": "user@example.com"})
#
# ImportError: attempted relative import with no known parent package

# %%
import os
import sys
backend_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'backend'))
sys.path.append(backend_path)

# Import everything from mongo module
from profile.mongo import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 7
#       4 sys.path.append(backend_path)
#       6 # Import everything from mongo module
# ----> 7 from profile.mongo import *
#
# ModuleNotFoundError: No module named 'profile.mongo'; 'profile' is not a package
